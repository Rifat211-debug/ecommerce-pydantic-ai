# %%
print("okay")
# Out:
# okay

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://salauddinalrifat_db_user:aa6OgYQp8Fursp5F@ecom-pydantic.wty4qbu.mongodb.net/?appName=ecom-pydantic"
)

# %%
db = client["ecom_db"]
collection = db["products"]

# %%
product = {
    "name" : "Men Casual Shirt",
    "price" : 999,
    "category" : "Man"
}

collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('6aa024380d186c6024cdad13'), acknowledged=True)

# %%
products = [
    {"name": "Jeans", "price": 1499, "category": "men"},
    {"name": "Kurti", "price": 999, "category": "women"},
    {"name": "Kids Jacket", "price": 1299, "category": "kids"}
]

collection.insert_many(products)
# Out:
# InsertManyResult([ObjectId('6aa025270d186c6024cdad14'), ObjectId('6aa025270d186c6024cdad15'), ObjectId('6aa025270d186c6024cdad16')], acknowledged=True)

# %%
all_products = collection.find()
for p in all_products:
    print(p)
# Out:
# {'_id': ObjectId('6aa024380d186c6024cdad13'), 'name': 'Men Casual Shirt', 'price': 999, 'category': 'Man'}
# {'_id': ObjectId('6aa025270d186c6024cdad14'), 'name': 'Jeans', 'price': 1499, 'category': 'men'}
# {'_id': ObjectId('6aa025270d186c6024cdad15'), 'name': 'Kurti', 'price': 999, 'category': 'women'}
# {'_id': ObjectId('6aa025270d186c6024cdad16'), 'name': 'Kids Jacket', 'price': 1299, 'category': 'kids'}

# %%
pro = collection.find_one({"name" : "Kurti"})
pro
# Out:
# {'_id': ObjectId('6aa025270d186c6024cdad15'),
#  'name': 'Kurti',
#  'price': 999,
#  'category': 'women'}

# %%
another = collection.find({"category" : "women"})
for i in another:
    print(i)
# Out:
# {'_id': ObjectId('6aa025270d186c6024cdad15'), 'name': 'Kurti', 'price': 999, 'category': 'women'}

# %%
collection.update_one(
    {"name" : "Jeans"},
    {"$set" : {"price" : 2323}} 
)
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000002c2'), 'opTime': {'ts': Timestamp(1788880691, 2), 't': 706}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1788880691, 2), 'signature': {'hash': b'\x1d\xe3o\xf7\\\x18\x92\xd8\xe2\xc6\x81\x08\xea\xf8\xb31\xe1\x10\x9d\x9b', 'keyId': 7623835948496715777}}, 'operationTime': Timestamp(1788880691, 2), 'updatedExisting': True}, acknowledged=True)

# %%
pro = collection.find_one({"name" : "Jeans"})
pro
# Out:
# {'_id': ObjectId('6aa025270d186c6024cdad14'),
#  'name': 'Jeans',
#  'price': 2323,
#  'category': 'men'}

# %%
collection.delete_one({"category" : "Jeans"})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff00000000000002c2'), 'opTime': {'ts': Timestamp(1788880767, 5), 't': 706}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1788880767, 5), 'signature': {'hash': b'\xb0Pe\x9d\x07H\xb7\x1b\x16Q\x15\x1c\x04:\xa3\x90y\xd7e\xad', 'keyId': 7623835948496715777}}, 'operationTime': Timestamp(1788880767, 5)}, acknowledged=True)

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 4, 'electionId': ObjectId('7fffffff00000000000002c2'), 'opTime': {'ts': Timestamp(1788880800, 5), 't': 706}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1788880800, 5), 'signature': {'hash': b'@\x99D\x0e\xae\xefIC\x13\xc5\xcd_\x05\xc8\xd5\xb2*-\xf3\xd4', 'keyId': 7623835948496715777}}, 'operationTime': Timestamp(1788880800, 5)}, acknowledged=True)

# %%
collection.drop()
